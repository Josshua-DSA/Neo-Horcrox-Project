# %%
import pycaret
import pandas as pd 

data_supply = pd.read_csv('d:/PENS-EEPIS/SDT A Semester 4 2026/Project TA/model/dataset/raw/DataCoSupplyChainDataset.csv', encoding = "latin1")

# %% [markdown]
# ## Raw Data

# %%
# buat ydata profiling
from ydata_profiling import ProfileReport
profile = ProfileReport(data_supply, title="Data Supply Chain Profiling Report", explorative=True)
profile.to_file("d:/PENS-EEPIS/SDT A Semester 4 2026/Project TA/model/reports/data_supply_profiling_report.html")

# tampilkan
profile.to_notebook_iframe()

# %% [markdown]
# ## Data Engineered

# %%
from ydata_profiling import ProfileReport
df = pd.read_csv('d:/PENS-EEPIS/SDT A Semester 4 2026/Project TA/model/dataset/engineered/data_engineeredEDA.csv')
profile = ProfileReport(df, title="Data Supply Chain Profiling Report", explorative=True)
profile.to_file("d:/PENS-EEPIS/SDT A Semester 4 2026/Project TA/model/reports/data_supply_engineered_report.html")

# tampilkan
profile.to_notebook_iframe()
